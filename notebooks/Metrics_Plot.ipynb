# %%
import json
import numpy as np
import pandas as pd
import glob
import os

# %%
folder_path = "results/"
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))
dfs = [pd.read_csv(file) for file in csv_files]

# %%
combined_df = pd.concat(dfs, ignore_index=True)
numeric_df = combined_df.select_dtypes(include="number") #Only numeric

# Compute mean and standard deviation
stats = pd.DataFrame({
    "mean": numeric_df.mean(),
    "std": numeric_df.std()
})

print(stats)

# %%
stats.to_csv("summary_stats.csv")

# %%
mean_df = numeric_df.mean().to_frame(name="mean")
std_df = numeric_df.std().to_frame(name="std")

# %%
optimization = ['Pruning_25', 'Pruning_75', 'PTQ_FP16', 'PTQ_INT8']

# %%
ax = mean_df.plot(
    kind="bar",
    yerr=std_df,
    capsize=3,
    color=["#DD3D2D", "#FEDA8B", "#6EA6CD"],
    figsize=(5, 3),
    width=0.85
)

#ax.margins(x=0.15)  
ax.set_ylabel("...")
plt.tight_layout()
plt.savefig('Optimization_comparison.png', dpi=300)
plt.show()
